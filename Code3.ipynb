# %%
def tic_tac_toe():
  """
  Plays a game of tic tac toe.
  """

  board = [" "] * 9
  player = "X"
  for i in range(9):
    draw_board(board)
    move = int(input("Enter your move (1-9): "))
    board[move - 1] = player
    if is_winner(board, player):
      print(f"Player {player} is the winner!")
      break
    player = "O" if player == "X" else "X"


def draw_board(board):
  """
  Draws the tic tac toe board.

  Args:
    board: The tic tac toe board.
  """

  print("-------------")
  for row in board:
    print(" | ".join(row))
  print("-------------")


def is_winner(board, player):
  """
  Checks if the player is a winner.

  Args:
    board: The tic tac toe board.
    player: The player's symbol.

  Returns:
    True if the player is a winner, False otherwise.
  """

  winning_combinations = [(1, 2, 3), (4, 5, 6), (7, 8, 9), (1, 4, 7), (2, 5, 8), (3, 6, 9), (1, 5, 9), (3, 5, 7)]
  for combination in winning_combinations:
    if all(board[i] == player for i in combination):
      return True
  return False


if __name__ == "__main__":
  tic_tac_toe()
# Out:
# -------------
#
#
#
#
#
#
#
#
#
# -------------
# -------------
# X
#
#
#
#
#
#
#
#
# -------------
# -------------
# X
# O
#
#
#
#
#
#
#
# -------------
# -------------
# X
# O
# X
#
#
#
#
#
#
# -------------
# -------------
# X
# O
# X
# O
#
#
#
#
#
# -------------
# -------------
# X
# O
# X
# O
#
#
#
#
#
# -------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 52
#      48   return False
#      51 if __name__ == "__main__":
# ---> 52   tic_tac_toe()
#
# Cell In[1], line 10, in tic_tac_toe()
#       8 for i in range(9):
#       9   draw_board(board)
# ---> 10   move = int(input("Enter your move (1-9): "))
#      11   board[move - 1] = player
#      12   if is_winner(board, player):
#
# ValueError: invalid literal for int() with base 10: ''
